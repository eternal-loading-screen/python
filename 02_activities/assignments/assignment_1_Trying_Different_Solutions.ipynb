# %% [markdown]
# # Assignment #1: Anagram Checker
#
# **Background**: Anagram Checker is a program that takes two words and determines if an anagram can be made from it. If so, the program will return `true`, otherwise `false`.

# %% [markdown]
# ## Submission Information
#
# 🚨 **Please review our [Assignment Submission Guide](https://github.com/UofT-DSI/onboarding/blob/main/onboarding_documents/submissions.md)** 🚨 for detailed instructions on how to format, branch, and submit your work. Following these guidelines is crucial for your submissions to be evaluated correctly.
#
# ### Submission Parameters:
# * Submission Due Date: `11:59 PM - May 4, 2025`
# * The branch name for your repo should be: `assignment-1`
# * What to submit for this assignment:
#     * This Jupyter Notebook (assignment_1.ipynb) should be populated and should be the only change in your pull request.
# * What the pull request link should look like for this assignment: `https://github.com/<your_github_username>/python/pull/<pr_id>`
#     * Open a private window in your browser. Copy and paste the link to your pull request into the address bar. Make sure you can see your pull request properly. This helps the technical facilitator and learning support staff review your submission easily.
#
# Checklist:
# - [ ] Created a branch with the correct naming convention.
# - [ ] Ensured that the repository is public.
# - [ ] Reviewed the PR description guidelines and adhered to them.
# - [ ] Verify that the link is accessible in a private browser window.
#
# If you encounter any difficulties or have questions, please don't hesitate to reach out to our team via our Slack at `#dc-help`. Our Technical Facilitators and Learning Support staff are here to help you navigate any challenges.

# %% [markdown]
# ### Part 1: Building the base Anagram Checker
#
# Given two valid strings, check to see if they are anagrams of each other. If it is, return `True`, else `False`. For this part, we can assume that uppercase letters are the same as if it was a lowercase character.
#
# Examples of anagrams:
# * Silent and Listen
# * Night and Think
#
# Example outputs:
# ```python
# anagram_checker("Silent", "listen") # True
# anagram_checker("Silent", "Night") # False
# anagram_checker("night", "Thing") # True
# ```

# %%
# For testing purposes, we will write our code in the function
def anagram_checker(word_a, word_b):
  # Your code here
    # Assuming you have to break up word a and word b on a per letter basis
    # handling for case sensitivity, so making it all lower case for the comparison
    # Office Hours: odd question, is there a way to use a function like sorted and a string method in the same line?
    # yes, something like sorted(a vector of words, key=str.lower) 

    # This code works
    word_a = str(word_a).lower()
    word_b = str(word_b).lower()

    unpack_word_a = sorted(word_a)
    # just showing what is happening
    print("The letters of the 1st word are: "+ str(unpack_word_a) )

    unpack_word_b = sorted(word_b)
    # just showing what is happening
    print("The letters of the 2nd word are: "+ str(unpack_word_b))
    result = unpack_word_a == unpack_word_b
  #  return result

    # result == True:
    # creating a variable that will be used in an IF statement
    # First we have to get a placeholder
    result1 = ""
    # Checking the results of the comparison
    if result == True:
        # Assigning it a value first
        result1 = "True"
        # The printing the result
        print(str(result1))
        print(str(result) + ", the words are anagrams.")
    else:
        result1 = "False"
        print(str(result1))
        print(str(result) + ", the words are not anagrams.")
    return result1

anagram_checker("Silent", "listen")
# Out:
# The letters of the 1st word are: ['e', 'i', 'l', 'n', 's', 't']
# The letters of the 2nd word are: ['e', 'i', 'l', 'n', 's', 't']
# True
# True, the words are anagrams.
# 'True'

# %%
# For testing purposes, we will write our code in the function
def anagram_checker(word_a, word_b):
  # Your code here
    # Assuming you have to break up word a and word b on a per letter basis
    # handling for case sensitivity, so making it all lower case for the comparison
    # Office Hours: odd question, is there a way to use a function like sorted and a string method in the same line?
    # yes, something like sorted(a vector of words, key=str.lower) 

    # This code works
    word_a = str(word_a).lower()
    word_b = str(word_b).lower()

    unpack_word_a = sorted(word_a)
    # just showing what is happening
    print("The letters of the 1st word are: "+ str(unpack_word_a) )

    unpack_word_b = sorted(word_b)
    # just showing what is happening
    print("The letters of the 2nd word are: "+ str(unpack_word_b))
    result = unpack_word_a == unpack_word_b
    # Adding an IF statement just prior to "return"
    if result == True:
        print("The words are anagrams")
    else:
        print("The words are not anagrams")
    return result
    
    


anagram_checker("Silent", "listen")
# Out:
# The letters of the 1st word are: ['e', 'i', 'l', 'n', 's', 't']
# The letters of the 2nd word are: ['e', 'i', 'l', 'n', 's', 't']
# The words are anagrams
# True

# %%
# For testing purposes, we will write our code in the function
def anagram_checker(word_a, word_b):
  # Your code here
    # Assuming you have to break up word a and word b on a per letter basis
    # handling for case sensitivity, so making it all lower case for the comparison
    # Office Hours: odd question, is there a way to use a function like sorted and a string method in the same line?
    # yes, something like sorted(a vector of words, key=str.lower) 

    unpack_word_a = sorted(str(word_a).lower())
    # just showing what is happening
    print("The letters of the 1st word are: "+ str(unpack_word_a) )

    unpack_word_b = sorted(str(word_b).lower())
    # just showing what is happening
    print("The letters of the 2nd word are: "+ str(unpack_word_b))
    result = unpack_word_a == unpack_word_b
    if result == True:
        print(str(result) + ", the words are anagrams.")
    else:
        print(str(result) + ", the words are not anagrams.")
    return result


anagram_checker("Silent", "listen") # True
# Out:
# The letters of the 1st word are: ['e', 'i', 'l', 'n', 's', 't']
# The letters of the 2nd word are: ['e', 'i', 'l', 'n', 's', 't']
# True, the words are anagrams.
# True

# %%
# For testing purposes, we will write our code in the function
def anagram_checker2(word_a, word_b):
  # Your code here
    # Assuming you have to break up word a and word b on a per letter basis
    # handling for case sensitivity, so making it all lower case for the comparison
    # Office Hours: odd question, is there a way to use a function like sorted and a string method in the same line?
    # yes, something like sorted(a vector of words, key=str.lower) 

    # This code works
    word_a = str(word_a).lower()
    word_b = str(word_b).lower()

    unpack_word_a = sorted(word_a)
    # just showing what is happening
    print("The letters of the 1st word are: "+ str(unpack_word_a) )

    unpack_word_b = sorted(word_b)
    # just showing what is happening
    print("The letters of the 2nd word are: "+ str(unpack_word_b))
    result = unpack_word_a == unpack_word_b

    # Maybe use a for loop
    length_word_a = len(unpack_word_a)
    length_word_b = len(unpack_word_b)
    print(length_word_a)
    print(length_word_b)

    temp = unpack_word_a[0]
    temp2 = unpack_word_b[0]
    print (temp)
    print (temp2)

    #Use a for loop to compare each letter to see what is different
    
    for letters in word_a:
      x = 0 
      x += 1 

    return result

    # How are they different?
    # if result == False:
    #     for unpack_word_a[0] 


anagram_checker2("Silent", "listen")
# Out:
# The letters of the 1st word are: ['e', 'i', 'l', 'n', 's', 't']
# The letters of the 2nd word are: ['e', 'i', 'l', 'n', 's', 't']
# 6
# e
# e
# True

# %%
anagram_checker("Silent", "Night")
# Out:
# The letters of the 1st word are: ['e', 'i', 'l', 'n', 's', 't']
# The letters of the 2nd word are: ['g', 'h', 'i', 'n', 't']
# False, the words are not anagrams.
# False

# %%
anagram_checker("night", "Thing")
# Out:
# The letters of the 1st word are: ['g', 'h', 'i', 'n', 't']
# The letters of the 2nd word are: ['g', 'h', 'i', 'n', 't']
# True, the words are anagrams.
# True

# %%
# Slightly cleaner code
# For testing purposes, we will write our code in the function
def anagram_checker2(word_a, word_b):
  # Your code here
    # Assuming you have to break up word a and word b on a per letter basis
    # handling for case sensitivity, so making it all lower case for the comparison
    # Office Hours: odd question, is there a way to use a function like sorted and a string method in the same line?
    # yes, something like sorted(a vector of words, key=str.lower) 

    unpack_word_a = sorted(word_a, key=str.lower)
    print("The letters of the 1st word are: "+ str(unpack_word_a) )

    unpack_word_b = sorted(word_b, key=str.lower)
    print("The letters of the 2nd word are: "+ str(unpack_word_b))
    result = unpack_word_a == unpack_word_b
    return print(result)


anagram_checker2("Silent", "listen")
anagram_checker2("Silent", "Night")
anagram_checker2("night", "Thing")
# Out:
# The letters of the 1st word are: ['e', 'i', 'l', 'n', 'S', 't']
# The letters of the 2nd word are: ['e', 'i', 'l', 'n', 's', 't']
# False
# The letters of the 1st word are: ['e', 'i', 'l', 'n', 'S', 't']
# The letters of the 2nd word are: ['g', 'h', 'i', 'N', 't']
# False
# The letters of the 1st word are: ['g', 'h', 'i', 'n', 't']
# The letters of the 2nd word are: ['g', 'h', 'i', 'n', 'T']
# False
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Slightly cleaner code
# For testing purposes, we will write our code in the function
def anagram_checker3(word_a, word_b):
  # Your code here
    # Assuming you have to break up word a and word b on a per letter basis
    # handling for case sensitivity, so making it all lower case for the comparison
    # Office Hours: odd question, is there a way to use a function like sorted and a string method in the same line?
    # yes, something like sorted(a vector of words, key=str.lower) 

    unpack_word_a = sorted(word_a, key=str.lower)
    print("The letters of the 1st word are: "+ str(unpack_word_a) )

    unpack_word_b = sorted(word_b, key=str.lower)
    print("The letters of the 2nd word are: "+ str(unpack_word_b))
    compare_words = unpack_word_a == unpack_word_b
    
    if compare_words == True:
        print("They are anagrams")
    else: 
        print("They are not anagrams")
    return  anagram_checker3("Silent", "listen")  



anagram_checker3("Silent", "listen")
anagram_checker3("Silent", "Night")
anagram_checker3("night", "Thing")

# %%
# For testing purposes, we will write our code in the function
def anagram_checker4(word_a, word_b):
  # Your code here
    # Assuming you have to break up word a and word b on a per letter basis
    # handling for case sensitivity, so making it all lower case for the comparison
    # Office Hours: odd question, is there a way to use a function like sorted and a string method in the same line?
    # yes, something like sorted(a vector of words, key=str.lower) 

    unpack_word_a = sorted(str(word_a).lower())
    # just showing what is happening
    print("The letters of the 1st word are: "+ str(unpack_word_a) )

    unpack_word_b = sorted(str(word_b).lower())
    # just showing what is happening
    print("The letters of the 2nd word are: "+ str(unpack_word_b))
    result = unpack_word_a == unpack_word_b
    return print( result )


anagram_checker4("Silent", "listen")
anagram_checker4("Silent", "Night")
anagram_checker4("night", "Thing")
# Out:
# The letters of the 1st word are: ['e', 'i', 'l', 'n', 's', 't']
# The letters of the 2nd word are: ['e', 'i', 'l', 'n', 's', 't']
# True
# The letters of the 1st word are: ['e', 'i', 'l', 'n', 's', 't']
# The letters of the 2nd word are: ['g', 'h', 'i', 'n', 't']
# False
# The letters of the 1st word are: ['g', 'h', 'i', 'n', 't']
# The letters of the 2nd word are: ['g', 'h', 'i', 'n', 't']
# True

# %% [markdown]
# ### Part 2: Expanding the functionality of the Anagram Checker
#
# Using your existing and functional anagram checker, let's add a boolean option called `is_case_sensitive`, which will return `True` or `False` based on if the two compared words are anagrams and if we are checking for case sensitivity.

# %%
def anagram_checker(word_a, word_b, is_case_sensitive):
  # Modify your existing code here

# Run your code to check using the words below:
anagram_checker("Silent", "listen", False) # True

# %%
anagram_checker("Silent", "Listen", True) # False

# %% [markdown]
# |Criteria|Pass|Fail|
# |---|---|---|
# |Code Execution|All code cells execute without errors.|Any code cell produces an error upon execution.|
# |Code Quality|Code is well-organized, concise, and includes necessary comments for clarity. E.g. Great use of variable names.|Code is unorganized, verbose, or lacks necessary comments. E.g. Single character variable names outside of loops.|
